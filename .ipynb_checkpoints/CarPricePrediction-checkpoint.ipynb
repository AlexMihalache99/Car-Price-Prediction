# %% [markdown]
# # Car Price Prediction
#
# Catalin Alexandru Mihalache

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder, StandardScaler
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPool2D
from keras.layers.core import Dense,Activation,Dropout,Flatten
from keras.utils import np_utils
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_log_error,mean_squared_error,mean_absolute_error,mean_absolute_percentage_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from keras.layers import Dense
from prettytable import PrettyTable

# %% [markdown]
# # Loading custom data

# %%
data = pd.read_csv("cars_info.csv")
data.head()
# Out:
#        Make                                              Model  \
# 0      Seat  Ibiza 1.4 Toca 5dr * REAR SENSORS / LOW MILEAG...
# 1    Jaguar                                    XE 2L R-Sport d
# 2      Ford                     Focus 2.0 ST-3 TDCI 5d 183 BHP
# 3    Toyota                    AYGO 1.0 VVT-I X-PLAY 5d 69 BHP
# 4  Vauxhall           Grandland X 1.2 SPORT NAV S/S 5d 129 BHP
#
#    Year of manufacture       Body  Doors  Seats Colour  Engine size    Price  \
# 0                 2014  Hatchback    5.0    5.0    Red          1.4   £6,995
# 1                 2018     Saloon    4.0    5.0  White          2.0  £23,025
# 2                 2018  Hatchback    5.0    5.0  Black          2.0  £18,500
# 3                 2017  Hatchback    5.0    4.0   Blue          1.0   £6,999
# 4                 2018  Hatchback    5.0    5.0   Blue          1.2  £16,499
#
#    Mileage Fuel type  Fuel economy Transmission  Horse power  Owners  \
# 0  42,848     Petrol          47.9       Manual         84.0     2.0
# 1  17,893        NaN          48.7    Automatic        177.0     1.0
# 2  51,149        NaN          67.3       Manual        182.0     2.0
# 3  33,411     Petrol          68.9       Manual         69.0     1.0
# 4  42,111     Petrol          55.4       Manual        128.0     1.0
#
#   Extraction time
# 0      16-11-2021
# 1      16-11-2021
# 2      16-11-2021
# 3      16-11-2021
# 4      16-11-2021

# %% [markdown]
# # Checking if the data has any null cells

# %%
data.isnull().sum()
# Out:
# Make                     0
# Model                    0
# Year of manufacture      0
# Body                   122
# Doors                  148
# Seats                   50
# Colour                   8
# Engine size             22
# Price                    0
# Mileage                  1
# Fuel type              506
# Fuel economy            37
# Transmission             0
# Horse power             27
# Owners                  59
# Extraction time          0
# dtype: int64

# %% [markdown]
# # Removing unimportant columns

# %%
data.drop('Fuel type', inplace=True, axis=1)
data.drop('Doors', inplace=True, axis=1)
data.drop('Body', inplace=True, axis=1)
data.drop('Extraction time', inplace=True, axis=1)
data.drop('Model', inplace=True, axis=1)
data.drop('Colour', inplace=True, axis=1)

# %%
data.head()
# Out:
#        Make  Year of manufacture  Seats  Engine size    Price  Mileage  \
# 0      Seat                 2014    5.0          1.4   £6,995  42,848
# 1    Jaguar                 2018    5.0          2.0  £23,025  17,893
# 2      Ford                 2018    5.0          2.0  £18,500  51,149
# 3    Toyota                 2017    4.0          1.0   £6,999  33,411
# 4  Vauxhall                 2018    5.0          1.2  £16,499  42,111
#
#    Fuel economy Transmission  Horse power  Owners
# 0          47.9       Manual         84.0     2.0
# 1          48.7    Automatic        177.0     1.0
# 2          67.3       Manual        182.0     2.0
# 3          68.9       Manual         69.0     1.0
# 4          55.4       Manual        128.0     1.0

# %% [markdown]
# # Checking if there are still missing values

# %%
data.isnull().sum()
# Out:
# Make                    0
# Year of manufacture     0
# Seats                  50
# Engine size            22
# Price                   0
# Mileage                 1
# Fuel economy           37
# Transmission            0
# Horse power            27
# Owners                 59
# dtype: int64

# %% [markdown]
# # Converting float columns to int

# %%
data['Seats'] = data['Seats'].fillna(0).astype(np.int64)
data['Owners'] = data['Owners'].fillna(0).astype(np.int64)
data['Fuel economy'] = data['Fuel economy'].fillna(0).astype(np.int64)
data['Engine size'] = data['Engine size'].fillna(0).astype(np.int64)
data["Horse power"] = data["Horse power"].fillna(0).astype(np.int64)

# %% [markdown]
# # Removing rows with missing values

# %%
data = data.loc[data['Seats'] != 0]
data = data.loc[data['Owners'] != 0]
data = data.loc[data['Fuel economy'] != 0]
data = data.loc[data['Engine size'] != 0]

# %% [markdown]
# # Checking if the cleaning was succesfull

# %%
data.isnull().sum()
# Out:
# Make                   0
# Year of manufacture    0
# Seats                  0
# Engine size            0
# Price                  0
# Mileage                0
# Fuel economy           0
# Transmission           0
# Horse power            0
# Owners                 0
# dtype: int64

# %% [markdown]
# # Checking how many samples are left

# %%
data.shape
# Out:
# (1283, 10)

# %% [markdown]
# # Convert Price and Mileage columns to numerical format

# %%
data["Price"] = data["Price"].str.replace(",", "")
data['Price'] = data['Price'].apply(lambda x: x.strip('£'))
data['Price'] = pd.to_numeric(data['Price'])

# %%
data["Mileage"] = data["Mileage"].str.replace(",", "")
data['Mileage'] = pd.to_numeric(data['Mileage'])

# %%
data.head()
# Out:
#        Make  Year of manufacture  Seats  Engine size  Price  Mileage  \
# 0      Seat                 2014      5            1   6995    42848
# 1    Jaguar                 2018      5            2  23025    17893
# 2      Ford                 2018      5            2  18500    51149
# 3    Toyota                 2017      4            1   6999    33411
# 4  Vauxhall                 2018      5            1  16499    42111
#
#    Fuel economy Transmission  Horse power  Owners
# 0            47       Manual           84       2
# 1            48    Automatic          177       1
# 2            67       Manual          182       2
# 3            68       Manual           69       1
# 4            55       Manual          128       1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1283 entries, 0 to 1402
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Make                 1283 non-null   object
#  1   Year of manufacture  1283 non-null   int64
#  2   Seats                1283 non-null   int64
#  3   Engine size          1283 non-null   int64
#  4   Price                1283 non-null   int64
#  5   Mileage              1283 non-null   int64
#  6   Fuel economy         1283 non-null   int64
#  7   Transmission         1283 non-null   object
#  8   Horse power          1283 non-null   int64
#  9   Owners               1283 non-null   int64
# dtypes: int64(8), object(2)
# memory usage: 110.3+ KB

# %% [markdown]
# # Encoding the car make column

# %%
data.Make.unique()
# Out:
# array(['Seat', 'Jaguar', 'Ford', 'Toyota', 'Vauxhall', 'Mercedes-Benz',
#        'Kia', 'BMW', 'DS', 'Audi', 'Mitsubishi', 'MINI', 'Hyundai',
#        'Land Rover', 'Skoda', 'Volvo', 'Peugeot', 'Volkswagen', 'Mazda',
#        'Dacia', 'Nissan', 'Citroen', 'Renault', 'Lexus', 'MERCEDES-BENZ',
#        'PORSCHE', 'AUDI', 'MITSUBISHI', 'LOTUS', 'JAGUAR', 'MG', 'Jeep',
#        'Suzuki', 'Honda', 'Fiat', 'Porsche', 'Abarth', 'Smart', 'Alfa',
#        'Infiniti'], dtype=object)

# %%
labelencoder = LabelEncoder()
data["Make_N"] = labelencoder.fit_transform(data["Make"])

# %% [markdown]
# # Encoding the transmission column

# %%
data.Transmission.unique()
# Out:
# array(['Manual', 'Automatic', 'Semi Automatic'], dtype=object)

# %%
data["Transmission_N"] = labelencoder.fit_transform(data["Transmission"])

# %%
data.head()
# Out:
#        Make  Year of manufacture  Seats  Engine size  Price  Mileage  \
# 0      Seat                 2014      5            1   6995    42848
# 1    Jaguar                 2018      5            2  23025    17893
# 2      Ford                 2018      5            2  18500    51149
# 3    Toyota                 2017      4            1   6999    33411
# 4  Vauxhall                 2018      5            1  16499    42111
#
#    Fuel economy Transmission  Horse power  Owners  Make_N  Transmission_N
# 0            47       Manual           84       2      32               1
# 1            48    Automatic          177       1      14               0
# 2            67       Manual          182       2       9               1
# 3            68       Manual           69       1      36               1
# 4            55       Manual          128       1      37               1

# %% [markdown]
# # Analyzing the price column

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(15, 10))
sns.distplot(data.Price)
plt.show()
# Out:
# C:\Users\alexm\OneDrive\Desktop\Dissertation\venv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Checking the correlations between columns

# %%
data.corr()
# Out:
#                      Year of manufacture     Seats  Engine size     Price  \
# Year of manufacture             1.000000  0.072862    -0.048878  0.411053
# Seats                           0.072862  1.000000    -0.035555  0.102469
# Engine size                    -0.048878 -0.035555     1.000000  0.623146
# Price                           0.411053  0.102469     0.623146  1.000000
# Mileage                        -0.675924  0.008172     0.072533 -0.318277
# Fuel economy                   -0.202625  0.026714    -0.147025 -0.216258
# Horse power                     0.020109  0.023252     0.779783  0.738373
# Owners                         -0.539607 -0.087713     0.101260 -0.121631
# Make_N                         -0.024998  0.057528    -0.125437 -0.061978
# Transmission_N                 -0.059485 -0.096519    -0.473285 -0.554848
#
#                       Mileage  Fuel economy  Horse power    Owners    Make_N  \
# Year of manufacture -0.675924     -0.202625     0.020109 -0.539607 -0.024998
# Seats                0.008172      0.026714     0.023252 -0.087713  0.057528
# Engine size          0.072533     -0.147025     0.779783  0.101260 -0.125437
# Price               -0.318277     -0.216258     0.738373 -0.121631 -0.061978
# Mileage              1.000000      0.315683     0.019487  0.308641  0.077156
# Fuel economy         0.315683      1.000000    -0.097038  0.034111  0.016727
# Horse power          0.019487     -0.097038     1.000000  0.098091 -0.117740
# Owners               0.308641      0.034111     0.098091  1.000000  0.024362
# Make_N               0.077156      0.016727    -0.117740  0.024362  1.000000
# Transmission_N      -0.006384      0.022492    -0.562043 -0.068186  0.016691
#
#                      Transmission_N
# Year of manufacture       -0.059485
# Seats                     -0.096519
# Engine size               -0.473285
# Price                     -0.554848
# Mileage                   -0.006384
# Fuel economy               0.022492
# Horse power               -0.562043
# Owners                    -0.068186
# Make_N                     0.016691
# Transmission_N             1.000000

# %%
plt.figure(figsize=(20, 15))
correlations = data.corr()
sns.heatmap(correlations, cmap="seismic", annot=True)
plt.show()

# %%
data.shape
# Out:
# (1283, 12)

# %% [markdown]
# # Splitting and scaling the data for training and testing

# %%
cols_drop=['Price','Transmission','Make']
x = data.drop(cols_drop,axis=1)
y = data['Price']
X_train,X_test,Y_train,Y_test=train_test_split(x, y, test_size=0.1, random_state=25)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Methods for training and evaluating models

# %%
# Model Building

def train_ml_model(x,y,model_type):

    if model_type=='lr':
        model=LinearRegression()

    elif model_type=='xgb':
        model=XGBRegressor()

    elif model_type=='rf':
        model=RandomForestRegressor()

    model.fit(X_train_scaled,np.log(y))

    return model

def model_evaluate(model,x,y):

    predictions=model.predict(x)
    predictions=np.exp(predictions)
    mse=mean_squared_error(y,predictions)
    mae=mean_absolute_error(y,predictions)
    mape=mean_absolute_percentage_error(y,predictions)
    msle=mean_squared_log_error(y,predictions)

    mse=round(mse,2)
    mae=round(mae,2)
    mape=round(mape,2)
    msle=round(msle,2)

    return [mse,mae,mape,msle]

# %% [markdown]
# # Building a Deep Learning model

# %%
model_dl_large=Sequential()
model_dl_large.add(Dense(64,input_dim=X_train_scaled.shape[1],activation='relu'))
model_dl_large.add(Dense(32,activation='relu'))
model_dl_large.add(Dense(16,activation='relu'))
model_dl_large.add(Dense(1,activation='linear'))
model_dl_large.compile(loss='mean_squared_error',optimizer='adam')
model_dl_large.summary()

# simple early stopping
es = EarlyStopping(monitor='val_loss', mode='min', patience = 3, verbose=1)

epochs=100
batch_size=10
model_dl_large.fit(X_train_scaled,np.log(Y_train),verbose=1,validation_data=(X_test_scaled,np.log(Y_test)),epochs=epochs,batch_size=batch_size, callbacks = [es])
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_32 (Dense)            (None, 64)                640
#
#  dense_33 (Dense)            (None, 32)                2080
#
#  dense_34 (Dense)            (None, 16)                528
#
#  dense_35 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 3,265
# Trainable params: 3,265
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 116/116 [==============================] - 0s 2ms/step - loss: 43.2005 - val_loss: 5.3852
# Epoch 2/100
# 116/116 [==============================] - 0s 931us/step - loss: 4.3687 - val_loss: 2.8979
# Epoch 3/100
# 116/116 [==============================] - 0s 1ms/step - loss: 2.4169 - val_loss: 1.7789
# Epoch 4/100
# 116/116 [==============================] - 0s 1ms/step - loss: 1.4044 - val_loss: 1.0998
# Epoch 5/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.8593 - val_loss: 0.7423
# Epoch 6/100
# 116/116 [==============================] - 0s 991us/step - loss: 0.5448 - val_loss: 0.5435
# Epoch 7/100
# 116/116 [==============================] - 0s 922us/step - loss: 0.3768 - val_loss: 0.4009
# Epoch 8/100
# 116/116 [==============================] - 0s 904us/step - loss: 0.2804 - val_loss: 0.3186
# Epoch 9/100
# 116/116 [==============================] - 0s 887us/step - loss: 0.2173 - val_loss: 0.2688
# Epoch 10/100
# 116/116 [==============================] - 0s 922us/step - loss: 0.1704 - val_loss: 0.2384
# Epoch 11/100
# 116/116 [==============================] - 0s 904us/step - loss: 0.1423 - val_loss: 0.2112
# Epoch 12/100
# 116/116 [==============================] - 0s 878us/step - loss: 0.1219 - val_loss: 0.1719
# Epoch 13/100
# 116/116 [==============================] - 0s 929us/step - loss: 0.1047 - val_loss: 0.1433
# Epoch 14/100
# 116/116 [==============================] - 0s 896us/step - loss: 0.0946 - val_loss: 0.1419
# Epoch 15/100
# 116/116 [==============================] - 0s 922us/step - loss: 0.0871 - val_loss: 0.1773
# Epoch 16/100
# 116/116 [==============================] - 0s 896us/step - loss: 0.0834 - val_loss: 0.1161
# Epoch 17/100
# 116/116 [==============================] - 0s 913us/step - loss: 0.0706 - val_loss: 0.1308
# Epoch 18/100
# 116/116 [==============================] - 0s 939us/step - loss: 0.0725 - val_loss: 0.1133
# Epoch 19/100
# 116/116 [==============================] - 0s 887us/step - loss: 0.0619 - val_loss: 0.1094
# Epoch 20/100
# 116/116 [==============================] - 0s 913us/step - loss: 0.0619 - val_loss: 0.1077
# Epoch 21/100
# 116/116 [==============================] - 0s 902us/step - loss: 0.0587 - val_loss: 0.1147
# Epoch 22/100
# 116/116 [==============================] - 0s 949us/step - loss: 0.0686 - val_loss: 0.0892
# Epoch 23/100
# 116/116 [==============================] - 0s 922us/step - loss: 0.0509 - val_loss: 0.1015
# Epoch 24/100
# 116/116 [==============================] - 0s 904us/step - loss: 0.0536 - val_loss: 0.0925
# Epoch 25/100
# 116/116 [==============================] - 0s 904us/step - loss: 0.0510 - val_loss: 0.0842
# Epoch 26/100
# 116/116 [==============================] - 0s 939us/step - loss: 0.0476 - val_loss: 0.0772
# Epoch 27/100
# 116/116 [==============================] - 0s 939us/step - loss: 0.0443 - val_loss: 0.0755
# Epoch 28/100
# 116/116 [==============================] - 0s 939us/step - loss: 0.0467 - val_loss: 0.0830
# Epoch 29/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.0440 - val_loss: 0.0784
# Epoch 30/100
# 116/116 [==============================] - 0s 1ms/step - loss: 0.0424 - val_loss: 0.0771
# Epoch 30: early stopping

# %% [markdown]
# # Plot the loss and validation loss of the dataset

# %%
history_df = pd.DataFrame(model_dl_large.history.history)
plt.figure(figsize=(20,10))
plt.plot(history_df['loss'], label='loss')
plt.plot(history_df['val_loss'], label='val_loss')
plt.xticks(np.arange(1,epochs+1,2))
plt.yticks(np.arange(1,max(history_df['loss']),0.5))
plt.legend()
plt.grid()

# %% [markdown]
# # Summary of all models

# %%
model_lr = train_ml_model(X_train_scaled,Y_train,'lr')
model_xgb = train_ml_model(X_train_scaled,Y_train,'xgb')
model_rf = train_ml_model(X_train_scaled,Y_train,'rf')

summary = PrettyTable(['Model','MSE','MAE','MAPE','MSLE'])
summary.add_row(['LR']+model_evaluate(model_lr,X_test_scaled,Y_test))
summary.add_row(['XGB']+model_evaluate(model_xgb,X_test_scaled,Y_test))
summary.add_row(['RF']+model_evaluate(model_rf,X_test_scaled,Y_test))
summary.add_row(['DL_LARGE']+model_evaluate(model_dl_large,X_test_scaled,Y_test))
print(summary)
# Out:
# +----------+-------------+---------+------+------+
# |  Model   |     MSE     |   MAE   | MAPE | MSLE |
# +----------+-------------+---------+------+------+
# |    LR    |  28970368.9 | 3474.27 | 0.18 | 0.05 |
# |   XGB    | 26330931.26 | 2608.62 | 0.13 | 0.03 |
# |    RF    | 25745007.46 | 2700.13 | 0.13 | 0.04 |
# | DL_LARGE | 37413419.39 | 3871.59 | 0.2  | 0.08 |
# +----------+-------------+---------+------+------+

# %% [markdown]
# # Plotting the Linear Regression graph

# %%
Y_pred=np.exp(model_lr.predict(X_test_scaled))
number_of_observations=100
X_ax = range(len(Y_test[:number_of_observations]))

plt.figure(figsize=(30,10))
plt.plot(X_ax, Y_test[:number_of_observations], label="True")
plt.plot(X_ax, Y_pred[:number_of_observations], label="Predicted")
plt.title("Car Price - True vs Predicted data")
plt.xlabel('Observation Number')
plt.ylabel('Price')
plt.xticks(np.arange(number_of_observations))
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Plotting the XGBoost graph

# %%
Y_pred=np.exp(model_xgb.predict(X_test_scaled))
number_of_observations=100
X_ax = range(len(Y_test[:number_of_observations]))

plt.figure(figsize=(30,10))
plt.plot(X_ax, Y_test[:number_of_observations], label="True")
plt.plot(X_ax, Y_pred[:number_of_observations], label="Predicted")
plt.title("Car Price - True vs Predicted data")
plt.xlabel('Observation Number')
plt.ylabel('Price')
plt.xticks(np.arange(number_of_observations))
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Plotting the Random Forest graph

# %%
Y_pred=np.exp(model_rf.predict(X_test_scaled))
number_of_observations=100
X_ax = range(len(Y_test[:number_of_observations]))

plt.figure(figsize=(30,10))
plt.plot(X_ax, Y_test[:number_of_observations], label="True")
plt.plot(X_ax, Y_pred[:number_of_observations], label="Predicted")
plt.title("Car Price - True vs Predicted data")
plt.xlabel('Observation Number')
plt.ylabel('Price')
plt.xticks(np.arange(number_of_observations))
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Plotting the Deep Learning graph

# %%
Y_pred=np.exp(model_dl_large.predict(X_test_scaled))
number_of_observations=100
X_ax = range(len(Y_test[:number_of_observations]))

plt.figure(figsize=(30,10))
plt.plot(X_ax, Y_test[:number_of_observations], label="True")
plt.plot(X_ax, Y_pred[:number_of_observations], label="Predicted")
plt.title("Car Price - True vs Predicted data")
plt.xlabel('Observation Number')
plt.ylabel('Price')
plt.xticks(np.arange(number_of_observations))
plt.legend()
plt.grid()
plt.show()
